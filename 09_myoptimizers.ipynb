# %% [markdown]
# # Optimizer Tweaks

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
#export
from exp.nb_08 import *

# %% [markdown]
# ## Imagenette Data

# %% [markdown]
# We grab the data from the previous notebook

# %%
path = datasets.untar_data(datasets.URLs.IMAGENETTE_160)

# %%
tfms = [make_rgb, ResizeFixed(128), to_byte_tensor, to_float_tensor]
bs = 128

il = ImageList.from_files(path, tfms=tfms)
sd = SplitData.split_by_func(il, partial(grandparent_splitter, valid_name='val'))
ll = label_by_func(sd, parent_labeler, proc_y=CategoryProcessor())
data = ll.to_databunch(bs, c_in=3, c_out=10, num_workers=4)

# %% [markdown]
# Then a model:

# %%
nfs = [32,64,128,256]

# %%
cbfs = [partial(AvgStatsCallback, accuracy), CudaCallback,
       partial(BatchTransformXCallback, norm_imagenette)]

# %% [markdown]
# This is the baseline of training with vanilla SGD

# %%
learn, run = get_learn_run(nfs, data, 0.4, conv_layer, cbs=cbfs)

# %%
run.fit(3, learn)
# Out:
# train: [1.7464109858485584, tensor(0.4012, device='cuda:0')]
# valid: [1.550636818272293, tensor(0.4792, device='cuda:0')]
# train: [1.3105918408094837, tensor(0.5624, device='cuda:0')]
# valid: [1.5839673318073249, tensor(0.4917, device='cuda:0')]
# train: [1.0227288759702715, tensor(0.6656, device='cuda:0')]
# valid: [1.2092119078423567, tensor(0.6051, device='cuda:0')]

# %% [markdown]
# ## Refining the optimizer

# %% [markdown]
# In Pytorch, the base optimizer in `torch.optim` is just a dictionary that stores the hyper-parameters and references to the parameters of the model we want to train in parameter groups(different groups can have different LRs and momentum/weight decay etc.. which is what lets us do discriminative learning rates).
#
# It contains a method `step` that will update our parameters with the gradients and a method `zero_grad` to detach and zero the gradients of all our parameters.
#
# We build the equivalent from scratch, only ours will be more flexible. In our implementation, the step_function loops over allthe parameters to execute the step using stepper functions that we have to provide when initializing the optimizer.

# %%
class Optimizer():
    def __init__(self, params, steppers, **defaults):
        #might be a generator
        self.param_groups = list(params)
        #ensure params is a list of lists
        if not isinstance(self.param_groups[0], list): self.param_groups = [self.param_groups]# list of 1 list
        # each param_group can have its own set of hyperparameters
        self.hypers = [{**defaults} for p in self.param_groups]
        self.steppers = listify(steppers)
        
    #just a convenience function down below
    # to go through every parameter you first gotta go through each param_group and then that.
    # going through only the ones whose gradients exist(as they're the ones you need to zero out)
    def grad_params(self):
        return [(p, hyper) for pg, hyper in zip(self.param_groups, self.hypers)
               for p in pg if p.grad is not None]
    
    def zero_grad(self):
        for p, hyper in self.grad_params():
            p.grad.detach_() # removes any gradient computation history
            p.grad.zero_()
            
    def step(self):
        for p, hyper in self.grad_params(): compose(p, self.steppers, **hyper)

# %% [markdown]
# To do basic SGD, this is what a step looks like:

# %%
#export
# example of a stepper
def sgd_step(p, lr, **kwargs):
    p.data.add_(-lr, p.grad.data)
    return p

# %%
opt_func = partial(Optimizer, steppers=[sgd_step])

# %% [markdown]
# Now that we have changed the optimizer, we will need to adjust the callbacks that were using properties from the Pytorch optimizer: in particular the hyper-parameters are in the list of dictionaries `opt.hypers` (Pytorch has everything in the list of param_groups).

# %%
#export 
class Recorder(Callback):
    def begin_fit(self): self.lrs, self.losses = [], []
    
    def after_batch(self):
        if not self.in_train: return
        self.lrs.append(self.opt.hypers[-1]['lr'])
        self.losses.append(self.loss.detach().cpu())

    def plot_lr(self): plt.plot(self.lrs)
    def plot_loss(self, skip_last=0): plt.plot(self.losses[:len(self.losses)-skip_last])

    def plot(self, skip_last=0, pgid=-1):
        losses = [o.item() for o in self.losses]
        lrs = self.lrs[pgid]
        n = len(losses)- skip_last
        plt.xscale('log')
        plt.plot(lrs[:n], losses[:n])

class ParamScheduler(Callback):
    _order=1
    def __init__(self, pname, sched_funcs): 
        self.pname, self.sched_funcs = pname, listify(sched_funcs)

    def begin_batch(self):
        if not self.in_train: return
        fs = self.sched_funcs
        if len(fs)==1: fs = fs*len(self.opt.param_groups)
        pos = self.n_epochs/self.epochs
        for f, h in zip(fs, self.opt.hypers): h[self.pname] =  f(pos)
        
class LR_find(Callback):
    def __init__(self, max_iter=100, min_lr=1e-6, max_lr=10):
        self.max_iter, self.min_lr, self.max_lr = max_iter, min_lr, max_lr
        self.best_loss = 1e9
        
    def begin_batch(self):
        if not self.in_train: return
        pos = self.n_iter/self.max_iter
        lr = self.min_lr * (self.max_lr/self.min_lr)**pos
        for pg in self.opt.hypers: pg['lr'] = lr
            
    def after_step(self):
        if self.n_iter>=self.max_iter or self.loss>self.best_loss*10:
            raise CancelTrainException()
        if self.loss <self.best_loss: self.best_loss = self.loss

# %% [markdown]
# So let's check that we didn't break anything and that recorder and param scheduler work perfectly.

# %%
sched = combine_scheds([0.3, 0.7], [sched_cos(0.3,0.6), sched_cos(0.6, 0.2)])

# %%
cbfs = [partial(AvgStatsCallback, accuracy),
       CudaCallback, Recorder, 
       partial(ParamScheduler, 'lr', sched)]

# %%
learn, run = get_learn_run(nfs, data, 0.4, conv_layer, cbs= cbfs, opt_func=opt_func)

# %%
# %time run.fit(1, learn)
# Out:
# train: [1.787781180694899, tensor(0.3816, device='cuda:0')]
# valid: [1.4796302746815286, tensor(0.5106, device='cuda:0')]
# CPU times: user 2.8 s, sys: 1.16 s, total: 3.96 s
# Wall time: 5.72 s

# %%
run.recorder.plot_loss()

# %%
run.recorder.plot_lr()

# %% [markdown]
# ## Weight Decay

# %% [markdown]
# By letting our model learn high parameters, it might fit all the data points in the training set with an over-complex function that has very sharp changes, wich will lead to overfitting.
# <img src="images/overfit.png" alt="Fitting vs over-fitting" width="600">
# Weight decay comes from the idea of L2 regulariztion, which consists in adding to your loss function the sum of all weights squared. Why do that? Because when we compute gradients, it will add a contribution to them that will encourage the weights to be as small as possible.

# %% [markdown]
# Limiting our weights from growing too much is going to hinder the training of our model, but it will yield to a state where it generalizes better. Going back to theory a bit, weight decay(or just`wd`) is a parameter that controls the sum of squares we add to our loss.
# ```python
# loss_with_wd = loss + (wd/2)* (weights**2).sum()
# ```
#
# In practice though, it would be very inefficien(and numerically unstable) to compute that big sum and add it to the loss. The derivative of `p**2` wrt `p` is `2*p`. So adding that big sum to our loss is exactly the same as doing:
# ```python
# weight.grad +=wd*weight
# ```
#
# for every weight in our model, which in the case of vanilla SGD is equivalent to updating the parameters with:
# ```python
# weight = weight - lr*(weight.grad + wd*weight)
# ```
# This technique is called "weight decay", as each weight is decayed by a factor of `lr*wd`, as its shows in this last formula.
#
# THis only works for standard SGD, as we have seen that with momentum, RMSprop and Adam, the update has some addtional formulas around the gradient. Inthose cases, the formula that comes from L2 regularization:
# ```python
# weight.grad += wd*weight
# ```
# is different from weight decay
# ```python
# new_weight = weight - lr* weight.grad - lr*wd*weight
# ```
# Most libraries use the first one, but as it was pointed ou in [Decoupled Weight Regularization](https://arxiv.org/pdf/1711.05101.pdf) by Ilya Loshchilov and Frank Hutter, it is better to use the second one with the Adam optimizer, which is why fastai made it its default.

# %% [markdown]
# Weight decaying is subtracting `lr*wd*weight` from the weights. We need this function to have an attribute `_defaults` so that we are sure there is an hyperparameter of the same name in our `Optimizer`.

# %%
#export
def weight_decay(p, lr, wd, **kwargs):
    p.data.mul_(1-lr*wd)
    return p
weight_decay._defaults = dict(wd=0.)

# %% [markdown]
# L2 regularization is adding `wd*weight` to the gradients.

# %%
#export
def l2_reg(p, lr, wd, **kwargs):
    p.grad.data.add_(wd, p.data)
    return p
l2_reg._defaults = dict(wd=0.)

# %% [markdown]
# Let's allow steppers to add to our `defaults`(which are the default values of all the hyper-parameters). This elper function adds in `dest` the key/values it finds while going through `os` and applying `f` when there was no `key` of the same name.

# %%
#export
def maybe_update(os, dest, f):
    for o in os:
        for k,v in f(o).items():
            if k not in dest: 
                #print(k, v)
                dest[k] = v
                
def get_defaults(d): return getattr(d, '_defaults', {})

# %% [markdown]
# This is the same as before, we just take the default values of the steppers wen none are provided in the kwargs

# %%
#export
class Optimizer():
    def __init__(self, params, steppers, **defaults):
        self.steppers = listify(steppers)
        # maybe update our defaults(defaults variable) with whaterver self.steppers has as defaults(from get_defaults)
        maybe_update(self.steppers, defaults, get_defaults)
        # might be a generator
        #print(defaults)
        self.param_groups = list(params)
        # ensure params is a list of lists
        if not isinstance(self.param_groups[0], list): self.param_groups = [self.param_groups]
        self.hypers = [{**defaults} for p in self.param_groups]
        
    def grad_params(self):
        return [(p, hyper) for pg, hyper in zip(self.param_groups, self.hypers)
               for p in pg if p.grad is not None]
    
    def zero_grad(self):
        for p, hyper in self.grad_params():
            p.grad.detach_()
            p.grad.zero_()
    
    def step(self):
        for p, hyper in self.grad_params(): compose(p, self.steppers, **hyper)

# %%
#export
sgd_opt = partial(Optimizer, steppers=[weight_decay, sgd_step])

# %%
# sgd step first followed by weight decay step. THis is the opposite of what we did above. 
# However the results don't have a lot of difference(8% accuracy which is likely some random seed)
# sgd_opt = partial(Optimizer, steppers=[sgd_step, weight_decay])

# %%
learn, run = get_learn_run(nfs, data, 0.4, conv_layer, cbs=cbfs, opt_func= sgd_opt)

# %% [markdown]
# Before trying to train, let's check the behaviour works as intended: when we don't provide a value for `wd`, we pull the corresponding default from `weight_decay`.

# %%
model = learn.model

# %%
opt = sgd_opt(model.parameters(), lr=0.1)

# %%
test_eq(opt.hypers[0]['wd'], 0.)
test_eq(opt.hypers[0]['lr'], 0.1)

# %% [markdown]
# But if we provide a value, it overides the default

# %%
opt = sgd_opt(model.parameters(), lr=0.1, wd=1e-4)
test_eq(opt.hypers[0]['wd'], 1e-4)
test_eq(opt.hypers[0]['lr'], 0.1)

# %% [markdown]
# Now let's fit.

# %%
cbfs = [partial(AvgStatsCallback, accuracy), CudaCallback]

# %%
learn, run = get_learn_run(nfs, data, 0.3, conv_layer, cbs=cbfs, opt_func=partial(sgd_opt, wd=0.01))

# %%
run.fit(5, learn)
# Out:
# train: [1.7784767646398776, tensor(0.3818, device='cuda:0')]
# valid: [1.7418008558917197, tensor(0.4148, device='cuda:0')]
# train: [1.3948812820123562, tensor(0.5309, device='cuda:0')]
# valid: [1.728005200039809, tensor(0.4064, device='cuda:0')]
# train: [1.236039766276798, tensor(0.5945, device='cuda:0')]
# valid: [1.529556876990446, tensor(0.4904, device='cuda:0')]
# train: [1.0916887920450946, tensor(0.6471, device='cuda:0')]
# valid: [1.3136627935907643, tensor(0.5659, device='cuda:0')]
# train: [0.9968665225010561, tensor(0.6774, device='cuda:0')]
# valid: [1.6808550208996815, tensor(0.4316, device='cuda:0')]

# %%
# run.fit(5, learn)
# Out:
# train: [1.7596789936239308, tensor(0.3935, device='cuda:0')]
# valid: [1.913136818272293, tensor(0.3340, device='cuda:0')]
# train: [1.370196187064368, tensor(0.5448, device='cuda:0')]
# valid: [3.7928734574044585, tensor(0.1231, device='cuda:0')]
# train: [1.1831991647085225, tensor(0.6172, device='cuda:0')]
# valid: [2.5291861564490445, tensor(0.2377, device='cuda:0')]
# train: [1.0717270666121026, tensor(0.6481, device='cuda:0')]
# valid: [1.573012913017516, tensor(0.4708, device='cuda:0')]
# train: [0.9699182859858485, tensor(0.6899, device='cuda:0')]
# valid: [1.460209121218153, tensor(0.5182, device='cuda:0')]

# %% [markdown]
# This is already better than baseline.

# %% [markdown]
# ## with momentum

# %% [markdown]
# Momentum requires to add some state. We need to save the moving average of the gradients to be able to do the step and store this inside the optimizer state. To do this, we introduce statistics. Statistics are objects with two methods:
# - `init_state`, that returns the intial state(a tensor of 0, for the moving average of the gradients.
# - `update`, that updates the state with the new gradient value.
#
# We also read the `_defaults` values of those objects, to allow them to provide default values to hyper-parameters.
#
# If you got 10 million activations in your model you now gotta keep track of 10 million more floats if you're using momentum.

# %%
#export
class StatefulOptimizer(Optimizer):
    def __init__(self, params, steppers, stats=None, **defaults):
        self.stats = listify(stats)
        maybe_update(self.stats, defaults, get_defaults)
        super().__init__(params, steppers, **defaults)
        self.state = {}
        
    def step(self):
        for p, hyper in self.grad_params():
            if p not in self.state:
                # create a state for p and call all statistics to initialize it.
                self.state[p] = {}
                maybe_update(self.stats, self.state[p], lambda o: o.init_state(p))
            state = self.state[p]
            for stat in self.stats: state = stat.update(p, state, **hyper)
            compose(p, self.steppers, **state, **hyper)
            self.state[p] = state

# %%
#export
class Stat():
    _defaults = {}
    def init_state(self, p): raise NotImplementedError
    def update(self, p, state, **kwargs): raise NotimplementedError

# %% [markdown]
# Here is an example of `Stat`

# %%
class AverageGrad(Stat):
    _defaults = dict(mom=0.9)
    
    def init_state(self, p): return {'grad_avg': torch.zeros_like(p.grad.data)}
    def update(self, p, state, mom, **kwargs):
        x = 1- mom
        z = p.grad.data * x
#         state['grad_avg'].mul_(mom).add_(p.grad.data)
        state['grad_avg'].mul_(mom).add_(z)
        return state

# %% [markdown]
# Then we add the momentum step( instead of using the gradients to perform the step, we use the averages)

# %%
#export
def momentum_step(p, lr, grad_avg, **kwargs):
    p.data.add_(-lr, grad_avg)
    return p

# %%
sgd_mom_opt = partial(StatefulOptimizer, steppers= [momentum_step, weight_decay],
                     stats=AverageGrad(), wd=0.01)

# %%
learn, run = get_learn_run(nfs, data, 0.3, conv_layer, cbs=cbfs, opt_func=sgd_mom_opt)

# %%
# regular mom
run.fit(5, learn)
# Out:
# train: [1.967034286223466, tensor(0.3425, device='cuda:0')]
# valid: [2.006731065883758, tensor(0.3228, device='cuda:0')]
# train: [1.454677145487908, tensor(0.5119, device='cuda:0')]
# valid: [1.7129835539410827, tensor(0.4364, device='cuda:0')]
# train: [1.2396333182622241, tensor(0.5917, device='cuda:0')]
# valid: [2.004812898089172, tensor(0.3554, device='cuda:0')]
# train: [1.0762133343014046, tensor(0.6484, device='cuda:0')]
# valid: [1.359288166799363, tensor(0.5569, device='cuda:0')]
# train: [0.974739322064104, tensor(0.6807, device='cuda:0')]
# valid: [1.5007596039012738, tensor(0.5427, device='cuda:0')]

# %%
# with newer mom
run.fit(5, learn)
# Out:
# train: [1.7804791870181644, tensor(0.3803, device='cuda:0')]
# valid: [1.9633583797770702, tensor(0.3327, device='cuda:0')]
# train: [1.3411468302817087, tensor(0.5544, device='cuda:0')]
# valid: [1.5221526671974521, tensor(0.4948, device='cuda:0')]
# train: [1.1418198941942126, tensor(0.6307, device='cuda:0')]
# valid: [1.690463027468153, tensor(0.4296, device='cuda:0')]
# train: [1.012653028137871, tensor(0.6783, device='cuda:0')]
# valid: [1.6605404060509554, tensor(0.4423, device='cuda:0')]
# train: [0.9124344489254409, tensor(0.7123, device='cuda:0')]
# valid: [2.036371292794586, tensor(0.3613, device='cuda:0')]

# %% [markdown]
# L2 regularization has no regularizing effect when combined with normalization. check paper https://arxiv.org/abs/1706.05350#:~:text=Batch%20Normalization%20is%20a%20commonly,decay%2C%20ostensibly%20to%20prevent%20overfitting.&text=Instead%2C%20regularization%20has%20an%20influence,on%20the%20effective%20learning%20rate.
# This guy is wrong too tho. We have NO IDEA as to what l2 regularization exactly does.

# %% [markdown]
# ### Momentum experiments

# %% [markdown]
# What does momentum do to the gradients exactly? Let's do some plots to find out!

# %%
x = torch.linspace(-4, 4, 200)
y = torch.randn(200) + 0.3
betas = [0.5, 0.7, 0.9, 0.99]

# %%
def plot_mom(f):
    _, axs = plt.subplots(2, 2, figsize=(12, 8))
    for beta, ax in zip(betas, axs.flatten()):
        ax.plot(y, linestyle="None", marker='.')
        avg, res = None, []
        for i,yi in enumerate(y):
            avg, p = f(avg, beta, yi, i)
            res.append(p)
            ax.plot(res, color='red')
            ax.set_title(f'beta={beta}')

# %% [markdown]
# This is the regular momentum

# %%
def mom1(avg, beta, yi, i):
    if avg is None: avg = yi
    res = beta*avg + yi
    return res,res
plot_mom(mom1)

# %% [markdown]
# As we can see, with too high a value of beta, it may go way too high with no way to change its course.
#
# Another way to smooth noisy data is to do an exponentially eighted moving average. In this case, there is a dampening of (1-beta) in front of the new value, which is less trusted than the current average. We'll define the `lin_comb` (linear combination) to make this easier( note that in the lesson this was named `ewma`).

# %%
#export
def lin_comb(v1, v2, beta): return beta*v1 + (1-beta)* v2

# %%
def mom2(avg, beta, yi, i):
    if avg is None: avg= yi
    avg = lin_comb(avg, yi, beta)
    return avg, avg
plot_mom(mom2)

# %% [markdown]
# We can see it gets to a zero-constant wen the data is purely random. If the data has a certain shape, it will get that shape(with some delay for high beta).

# %%
y = 1- (x/3)**2 + torch.randn(200)*0.1

# %%
y[0] = 1

# %%
plot_mom(mom2)

# %% [markdown]
# Debiasing is here to correct the wrong information we may have in the very first batch. The debias term corresponds to the sum of the coefficient in our moving averages. At the time step i, our average is:
#
# $\begin{align*}
# avg_{i} &= \beta\ avg_{i-1} + (1-\beta)\ v_{i} = \beta\ (\beta\ avg_{i-2} + (1-\beta)\ v_{i-1}) + (1-\beta)\ v_{i} \\
# &= \beta^{2}\ avg_{i-2} + (1-\beta)\ \beta\ v_{i-1} + (1-\beta)\ v_{i} \\
# &= \beta^{3}\ avg_{i-3} + (1-\beta)\ \beta^{2}\ v_{i-2} + (1-\beta)\ \beta\ v_{i-1} + (1-\beta)\ v_{i} \\
# &\vdots \\
# &= (1-\beta)\ \beta^{i}\ v_{0} + (1-\beta)\ \beta^{i-1}\ v_{1} + \cdots + (1-\beta)\ \beta^{2}\ v_{i-2} + (1-\beta)\ \beta\  v_{i-1} + (1-\beta)\ v_{i}
# \end{align*}$
#
# and so the sum of the coefficients is
#
# $\begin{align*}
# S &=(1-\beta)\ \beta^{i} + (1-\beta)\ \beta^{i-1} + \cdots + (1-\beta)\ \beta^{2} + (1-\beta)\ \beta + (1-\beta) \\
# &= (\beta^{i} - \beta^{i+1}) + (\beta^{i-1} - \beta^{i}) + \cdots + (\beta^{2} - \beta^{3}) + (\beta - \beta^{2}) + (1-\beta) \\
# &= 1 - \beta^{i+1}
# \end{align*}$
#
# since all the other terms cancel out each other.
#
# By dividing by this term, we make our moving average a true average (in the sense that all the coefficients we used for the average sum up to 1).

# %%
def mom3(avg, beta, yi, i):
    if avg is None: avg=0
    avg= lin_comb(avg, yi, beta)
    return avg, avg/(1-beta**(i+1))
                     
plot_mom(mom3)

# %% [markdown]
# We'll use this concept on debiasing in Adam now.

# %% [markdown]
# ## Adam and friends

# %% [markdown]
# In adam, we use the gradient averages but with dampening( not like in SGD with momentum), so let's add this to the `AverageGrad` class

# %%
#export
class AverageGrad(Stat):
    _defaults= dict(mom=0.9)
    
    def __init__(self, dampening:bool=False): self.dampening = dampening
    def init_state(self, p): return {'grad_avg': torch.zeros_like(p.grad.data)}
    def update(self, p, state, mom, **kwargs):
        state['mom_damp'] = 1-mom if self.dampening else 1.
        state['grad_avg'].mul_(mom).add_(state['mom_damp'], p.grad.data)
        return state

# %% [markdown]
# We also need to track the moving averages of the gradient squared.

# %%
#export
class AverageSqrGrad(Stat):
    _defaults = dict(sqr_mom=0.99)
    
    def __init__(self, dampening:bool=True): self.dampening=dampening
    def init_state(self, p): return {'sqr_avg': torch.zeros_like(p.grad.data)} 
    def update(self, p, state, mom, **kwargs):
        state['sqr_damp'] = 1-mom if self.dampening else 1.
        state['sqr_avg'].mul_(mom).addcmul_(state['sqr_damp'], p.grad.data, p.grad.data)
        return state

# %% [markdown]
# We will also need the number of steps done during training for the debiasing.

# %%
#export
class StepCount(Stat):
    def init_state(self, p): return {'step': 0}
    def update(self, p, state, **kwargs):
        state['step'] +=1
        return state

# %% [markdown]
# This helper function computes the debias term. If we dampening, `damp=1-mom` and we get the same result as before. If we don't use dampening, (`damp=1.`) we will need to divide by `1-mom` because that term is missing everywhere.

# %%
#export
def debias(mom, damp, step): return damp *(1-mom**step)

# %% [markdown]
# Then the Adam step is just the following

# %%
#export
def adam_step(p, lr, mom, mom_damp, step, sqr_mom, sqr_damp, grad_avg, sqr_avg, eps, **kwargs):
    debias1 = debias(mom,     mom_damp, step)
    debias2 = debias(sqr_mom, sqr_damp, step)
    p.data.addcdiv_(-lr/debias1, grad_avg, (sqr_avg/debias2).sqrt() + eps)
    return p
adam_step._defaults = dict(eps=1e-5)

# %%
#export
def adam_opt(xtra_step=None, **kwargs):
    return partial(StatefulOptimizer, steppers=[adam_step, weight_decay]+ listify(xtra_step),
                  stats=[AverageGrad(dampening=True), AverageSqrGrad(), StepCount()], **kwargs)

# %%
learn, run = get_learn_run(nfs, data, 0.001, conv_layer, cbs=cbfs, opt_func=adam_opt())

# %%
run.fit(5, learn)
# Out:
# train: [1.726938727690358, tensor(0.4030, device='cuda:0')]
# valid: [1.7418430284633757, tensor(0.4183, device='cuda:0')]
# train: [1.726938727690358, tensor(0.4030, device='cuda:0')]
# valid: [1.7418430284633757, tensor(0.4183, device='cuda:0')]
# train: [1.2322078748745908, tensor(0.5936, device='cuda:0')]
# valid: [1.5168356886942675, tensor(0.5203, device='cuda:0')]
# train: [1.2322078748745908, tensor(0.5936, device='cuda:0')]
# valid: [1.5168356886942675, tensor(0.5203, device='cuda:0')]
# train: [0.9495661005650016, tensor(0.6879, device='cuda:0')]
# valid: [1.282506717754777, tensor(0.5855, device='cuda:0')]
# train: [0.9495661005650016, tensor(0.6879, device='cuda:0')]
# valid: [1.282506717754777, tensor(0.5855, device='cuda:0')]
# train: [0.6980313329186028, tensor(0.7715, device='cuda:0')]
# valid: [1.248994078423567, tensor(0.6145, device='cuda:0')]
# train: [0.6980313329186028, tensor(0.7715, device='cuda:0')]
# ...

# %% [markdown]
# ## LAMB optimizer

# %% [markdown]
# It's super easy to implement a new optimizer. This is LAMB from a [very recent paper](https://arxiv.org/pdf/1904.00962.pdf):
# $\begin{align}
# g_{t}^{l} &= \nabla L(w_{t-1}^{l}, x_{t}) \\
# m_{t}^{l} &= \beta_{1} m_{t-1}^{l} + (1-\beta_{1}) g_{t}^{l} \\
# v_{t}^{l} &= \beta_{2} v_{t-1}^{l} + (1-\beta_{2}) g_{t}^{l} \odot g_{t}^{l} \\
# m_{t}^{l} &= m_{t}^{l} / (1 - \beta_{1}^{t}) \\
# v_{t}^{l} &= v_{t}^{l} / (1 - \beta_{2}^{t}) \\
# r_{1} &= \|w_{t-1}^{l}\|_{2} \\
# s_{t}^{l} &= \frac{m_{t}^{l}}{\sqrt{v_{t}^{l} + \epsilon}} + \lambda w_{t-1}^{l} \\
# r_{2} &= \| s_{t}^{l} \|_{2} \\
# \eta^{l} &= \eta * r_{1}/r_{2} \\
# w_{t}^{l} &= w_{t}^{l-1} - \eta_{l} * s_{t}^{l} \\
# \end{align}$

# %%
def lamb_step(p, lr, mom, mom_damp, step, sqr_mom, sqr_damp, grad_avg, sqr_avg, eps, wd, **kwargs):
    debias1 = debias(mom,     mom_damp, step)
    debias2 = debias(sqr_mom, sqr_damp, step)
    r1 = p.data.pow(2).mean().sqrt()
    step = (grad_avg/debias1) / ((sqr_avg/debias2).sqrt()+ eps) + wd*p.data
    r2 = step.pow(2).mean().sqrt()
    p.data.add_(-lr * min(r1/r2, 10), step)
    return p
lamb_step._defaults = dict(eps= 1e-6, wd=0.)

# %%
lamb = partial(StatefulOptimizer, steppers= lamb_step, stats=[AverageGrad(dampening=True), AverageSqrGrad(), StepCount()])

# %%
learn, run = get_learn_run(nfs, data, 0.003, conv_layer, cbs=cbfs, opt_func=lamb)

# %%
run.fit(5, learn)
# Out:
# train: [1.8481370541371844, tensor(0.3595, device='cuda:0')]
# valid: [1.6039806429140127, tensor(0.4627, device='cuda:0')]
# train: [1.8481370541371844, tensor(0.3595, device='cuda:0')]
# valid: [1.6039806429140127, tensor(0.4627, device='cuda:0')]
# train: [1.337963539741525, tensor(0.5596, device='cuda:0')]
# valid: [1.4802206906847133, tensor(0.5208, device='cuda:0')]
# train: [1.337963539741525, tensor(0.5596, device='cuda:0')]
# valid: [1.4802206906847133, tensor(0.5208, device='cuda:0')]
# train: [1.062502784579945, tensor(0.6567, device='cuda:0')]
# valid: [1.3481089520302547, tensor(0.5722, device='cuda:0')]
# train: [1.062502784579945, tensor(0.6567, device='cuda:0')]
# valid: [1.3481089520302547, tensor(0.5722, device='cuda:0')]
# train: [0.8329386620980305, tensor(0.7309, device='cuda:0')]
# valid: [1.2766331608280255, tensor(0.5969, device='cuda:0')]
# train: [0.8329386620980305, tensor(0.7309, device='cuda:0')]
# ...

# %% [markdown]
# Other recent variants of optimizers:
# - [Large Batch Training of Convolutional Networks](https://arxiv.org/abs/1708.03888) (LARS also uses weight statistics, not just gradient statistics. Can you add that to this class?)
# - [Adafactor: Adaptive Learning Rates with Sublinear Memory Cost](https://arxiv.org/abs/1804.04235) (Adafactor combines stats over multiple sets of axes)
# - [Adaptive Gradient Methods with Dynamic Bound of Learning Rate](https://arxiv.org/abs/1902.09843)

# %% [markdown]
# ## Export

# %%
# !python notebook2script.py 09_optimizers.ipynb
# Out:
# Converted 09_optimizers.ipynb to exp/nb_09.py
# Converted 09_optimizers.ipynb to exp/nb_09.py
